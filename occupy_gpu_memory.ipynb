# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "2"

# %%
import torch

t1 = torch.ones((1024,1024,1024),dtype=torch.float32).to('cuda')
t2 = torch.ones((1024,1024,1024),dtype=torch.float32).to('cuda')
# t3 = torch.ones((1024,1024,1024),dtype=torch.float32).to('cuda')
# t4 = torch.ones((1024,1024,1024),dtype=torch.float32).to('cuda')

while True:
    t5=t1+t2#+t3#+t4
    del t5
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 9
#       5 # t3 = torch.ones((1024,1024,1024),dtype=torch.float32).to('cuda')
#       6 # t4 = torch.ones((1024,1024,1024),dtype=torch.float32).to('cuda')
#       8 while True:
# ----> 9     t5=t1+t2#+t3#+t4
#      10     del t5
#
# KeyboardInterrupt:
